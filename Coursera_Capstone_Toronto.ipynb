# %% [markdown]
# # Coursera Capstone - Toronto Segmentation and Clustering

# %% [markdown]
# ## Overview

# %% [markdown]
# This notebook attempts to pull relevant information from the Toronto Wiki page. Below is a brief outline of useful resources for completing this Assignment (for my future reference and others):
#
#    * Portions of the Python for Data Science labs were helpful in the webscraping portion of this assignment. FakeAlbumCoverGame snippets were especially helpful for the BeautifulSoup portion.
#    *

# %% [markdown]
# ## Start off by importing libraries

# %%
# !pip install bs4 
# !pip install lxml
import numpy as np
import pandas as pd
import requests
import urllib.request, urllib.parse, urllib.error

from bs4 import BeautifulSoup #can use BeautifulSoup to parse website
# Out:
# ...
# You are using pip version 19.0, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# ...
# You are using pip version 19.0, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %% [markdown]
# Here's the URL we're scraping (I hate that word, but it's the industry vernacular :( ).
#
# 1. Use the function .get() from the requests library (store results in a variable).
#
# 2. Use the data attribute text to extract the XML as a text file (store results in a variable).

# %%
website_url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page = requests.get(website_url) #response.status_code == 200 if successful
soup = BeautifulSoup(page.content,'html.parser')

#print(soup)

# %%
#web scraping using beautiful soup

#web_link = r'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
#raw_page = urllib.request.urlopen(web_link)
#soup = BeautifulSoup(raw_page)

# %%
#web scraping using pandas
#note: set header = 0 to use the first row as column headers

d = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M', header=0)
#type(d) #prints 'list'

#print(len(d)) #prints '3' since there are 3 tables on this page. the one we want to use is index=0
#print(d[0])
#format of df['column_name']['row_#_in_column_name']

# %%
#set the target table to a 'dataframe'
df = d[0]

#check the shape of df
print(len(df)) #prints '289' is the # of rows (including the column name row)
print(df.shape) #prints '(289, 3)'
print(df.columns) #prints 'Index(['Postcode', 'Borough', 'Neighbourhood'], dtype='object')'
#print(df['Postcode'][0])
#print(df['Borough'][0])
#print(df['Neighbourhood'][0])
# Out:
# 288
# (288, 3)
# Index(['Postcode', 'Borough', 'Neighbourhood'], dtype='object')

# %%
#confirming type dataframe
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#view the df
print(df)
# Out:
#     Postcode           Borough  \
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 9        M8A      Not assigned
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 13       M2B      Not assigned
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 20       M7B      Not assigned
# 21       M8B      Not assigned
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# ...

# %%
#export to csv (for manual validation, if desired)
df.to_csv('df_toronto.csv')

# %%
#use the groupby function to analyze the neighborhood counts per postal code
df_groupby = df.groupby(['Postcode']).count() #'Postcode', axis=0
df_groupby
# Out:
#           Borough  Neighbourhood
# Postcode
# M1A             1              1
# M1B             2              2
# M1C             3              3
# M1E             3              3
# M1G             1              1
# M1H             1              1
# M1J             1              1
# M1K             3              3
# M1L             3              3
# M1M             3              3
# M1N             2              2
# M1P             3              3
# M1R             2              2
# M1S             1              1
# M1T             3              3
# M1V             4              4
# M1W             1              1
# M1X             1              1
# M1Y             1              1
# M1Z             1              1
# M2A             1              1
# M2B             1              1
# M2C             1              1
# M2E             1              1
# M2G             1              1
# M2H             1              1
# M2J             3              3
# ...

# %%
# select Postcodes with  counts >1
#df_groupby_countGT1 = 
df_groupby_countGT1 = df.groupby(['Postcode']).filter(lambda x: len(x) > 1)
df_groupby_countGT1
# Out:
#     Postcode           Borough             Neighbourhood
# 4        M5A  Downtown Toronto              Harbourfront
# 5        M5A  Downtown Toronto               Regent Park
# 6        M6A        North York          Lawrence Heights
# 7        M6A        North York            Lawrence Manor
# 11       M1B       Scarborough                     Rouge
# 12       M1B       Scarborough                   Malvern
# 15       M4B         East York          Woodbine Gardens
# 16       M4B         East York             Parkview Hill
# 17       M5B  Downtown Toronto                   Ryerson
# 18       M5B  Downtown Toronto           Garden District
# 22       M9B         Etobicoke                Cloverdale
# 23       M9B         Etobicoke                 Islington
# 24       M9B         Etobicoke              Martin Grove
# 25       M9B         Etobicoke          Princess Gardens
# 26       M9B         Etobicoke           West Deane Park
# ...

# %%
df_groupby_countGT1.shape
# Out:
# (165, 3)

# %%
#export to csv (check to see if filter matches what's expected, if desired)
#df_groupby_countGT1.to_csv('df_toronto_filtered.csv')

# %%
#note: 165 rows matches expected output for count >1

# %%
df_groupby_countGT1.groupby(['Postcode']).count()
# Out:
#           Borough  Neighbourhood
# Postcode
# M1B             2              2
# M1C             3              3
# M1E             3              3
# M1K             3              3
# M1L             3              3
# M1M             3              3
# M1N             2              2
# M1P             3              3
# M1R             2              2
# M1T             3              3
# M1V             4              4
# M2J             3              3
# M2L             2              2
# M2M             2              2
# M3C             2              2
# M3H             3              3
# M3J             2              2
# M3K             2              2
# M4B             2              2
# M4K             2              2
# M4L             2              2
# M4T             2              2
# M4V             5              5
# M4X             2              2
# M5A             2              2
# M5B             2              2
# M5H             3              3
# ...

# %%
#check the number of unique records
df['Postcode'].nunique()
# Out:
# 180

# %%
#check the number of unique records
df['Borough'].nunique()
# Out:
# 12

# %%
#check the number of unique records
df['Neighbourhood'].nunique()
# Out:
# 209

# %%
#df test
df_test = df.iloc[2:].rename(columns=df.iloc[:2].apply(lambda x: x.str.cat(sep=' ')))

# %%
#observe the html text
#print(soup)

# %%
#print(soup.prettify()) #prints the cleaned up structural information for the webpage

# %%
#Examples of how to navigate BeautifulSoup
#print(soup.title) #<title>List of postal codes of Canada: M - Wikipedia</title>
#print(soup.title.name) #title
#print(soup.head.name) #<head>
#print(soup.body.a) #<a id="top"></a>
#print(soup.title.string) #List of postal codes of Canada: M - Wikipedia
#print(soup.table) #prints the table on the webpage

# %% [markdown]
# #### Notes for next steps:
#   *tables appear to be part of the tr, /tr
#   *maybe search for row in tr

# %%
# this portion prints links on the webpage
#for link in soup.find_all('a'):
#    print(link.get('href'))

#print(soup.get_text) # prints the text from the website
